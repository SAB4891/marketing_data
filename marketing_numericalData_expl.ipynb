# %% [markdown]
# ### Exploration of Numerical variables with the target y (subscribed : Y or N)

# %%
# Exploring Age (numerical predictor with the target variable)
import seaborn as sns

# %%
train_data.age.plot.hist(grid=True, bins=15, rwidth=0.9, color='#607c8e')
plt.xlabel('Age')
plt.ylabel('counts')
plt.show()

# %%
# Histogram of Age with target variable(y) overlay 


age_yes = train_data[train_data.y=='yes']['age']
age_no = train_data[train_data.y=='no']['age']

plt.hist([age_yes, age_no], bins = 15, stacked = True, rwidth=0.9)
plt.legend(['subscribed = Yes', 'subscribed = No'])
plt.title('Histogram of Age with subscription Overlay')
plt.xlabel("Age"); plt.ylabel("counts"); plt.show()

# %%
(n, bins, patches) = plt.hist([age_yes, age_no], bins =15, stacked = True, rwidth=0.9)

# %%
n_table = np.column_stack((n[0], n[1]))
n_table
# Out:
# array([[1.220e+02, 3.790e+02],
#        [4.630e+02, 2.836e+03],
#        [1.153e+03, 9.794e+03],
#        [7.850e+02, 8.166e+03],
#        [4.900e+02, 6.068e+03],
#        [4.580e+02, 5.890e+03],
#        [3.720e+02, 3.825e+03],
#        [3.830e+02, 3.320e+03],
#        [1.240e+02, 2.910e+02],
#        [8.800e+01, 1.970e+02],
#        [9.100e+01, 2.110e+02],
#        [6.000e+01, 1.120e+02],
#        [3.500e+01, 6.500e+01],
#        [1.400e+01, 3.000e+01],
#        [2.000e+00, 4.000e+00]])

# %%
n_norm = n_table / n_table.sum(axis=1)[:, None]

# %%
# NORMALIZED histogram of Age with subscription overlay 

ourbins = np.column_stack((bins[0:15], bins[1:16]))

p1 = plt.bar(x = ourbins[:,0], height = n_norm[:,0], width = ourbins[:, 1] - ourbins[:, 0], edgecolor='white')
p2 = plt.bar(x = ourbins[:,0], height = n_norm[:,1], width = ourbins[:, 1] - ourbins[:, 0], bottom = n_norm[:,0], edgecolor='white')

plt.legend(['subscription= Yes', 'subscription = No'])
plt.title('NORMALIZED Histogram of Age with subscription Overlay')
plt.xlabel("Age"); plt.ylabel("counts"); plt.show()

# %% [markdown]
# ***

# %%
# Exploring Campaign-nbr of contact performed on clinet (numerical predictor with the target variable)
import seaborn as sns

# %%
train_data.campaign.plot.hist(grid=True, bins=12, rwidth=0.9, color='#607c8e')
plt.xlabel('nbr of times contacted')
plt.ylabel('counts')
plt.show()

# %%
# Histogram of campaign-nb of times contacted- with target variable(y) overlay 


campaign_yes = train_data[train_data.y=='yes']['campaign']
campaign_no = train_data[train_data.y=='no']['campaign']

plt.hist([campaign_yes, campaign_no], bins = 12, stacked = True, rwidth=0.9)
plt.legend(['subscribed = Yes', 'subscribed = No'])
plt.title('Histogram of nbr of times contacted with subscription Overlay')
plt.xlabel("nbr of times contacted"); plt.ylabel("counts"); plt.show()

# %%
(n, bins, patches) = plt.hist([campaign_yes, campaign_no], bins =12, stacked = True, rwidth=0.9)

# %%
n_table = np.column_stack((n[0], n[1]))
n_table
# Out:
# array([[4.4540e+03, 3.7803e+04],
#        [1.5900e+02, 2.5160e+03],
#        [2.0000e+01, 4.6300e+02],
#        [6.0000e+00, 2.1900e+02],
#        [1.0000e+00, 8.7000e+01],
#        [0.0000e+00, 5.0000e+01],
#        [0.0000e+00, 3.2000e+01],
#        [0.0000e+00, 9.0000e+00],
#        [0.0000e+00, 6.0000e+00],
#        [0.0000e+00, 2.0000e+00],
#        [0.0000e+00, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00]])

# %%
n_norm = n_table / n_table.sum(axis=1)[:, None]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
# NORMALIZED histogram of nb of times contacted with subscription overlay 

ourbins = np.column_stack((bins[0:12], bins[1:13]))

p1 = plt.bar(x = ourbins[:,0], height = n_norm[:,0], width = ourbins[:, 1] - ourbins[:, 0], edgecolor='white')
p2 = plt.bar(x = ourbins[:,0], height = n_norm[:,1], width = ourbins[:, 1] - ourbins[:, 0], bottom = n_norm[:,0], edgecolor='white')

plt.legend(['subscription= Yes', 'subscription = No'])
plt.title('NORMALIZED Histogram of nb of times contacted with subscription Overlay')
plt.xlabel("nb of times contacted"); plt.ylabel("counts"); plt.show()

# %% [markdown]
# ***

# %%
# Exploring cons.conf.idx (numerical predictor with the target variable)
import seaborn as sns

# %%
train_data["cons.conf.idx"].plot.hist(grid=True, bins=15, rwidth=0.9, color='#607c8e')
plt.xlabel('cons.conf.idx')
plt.ylabel('counts')
plt.show()

# %%
# Histogram of cons.conf.idx with target variable(y) overlay 

cons_conf_yes = train_data[train_data.y=='yes']['cons.conf.idx']
cons_conf_no = train_data[train_data.y=='no']['cons.conf.idx']

plt.hist([cons_conf_yes, cons_conf_no], bins = 15, stacked = True, rwidth=0.9)
plt.legend(['subscribed = Yes', 'subscribed = No'])
plt.title('Histogram of cons.conf.idx with subscription Overlay')
plt.xlabel("cons_conf_idx"); plt.ylabel("counts"); plt.show()

# %%
(n, bins, patches) = plt.hist([cons_conf_yes, cons_conf_no], bins =15, stacked = True, rwidth=0.9)

# %%
n_table = np.column_stack((n[0], n[1]))
n_table
# Out:
# array([[2.7700e+02, 6.1400e+02],
#        [0.0000e+00, 0.0000e+00],
#        [9.6600e+02, 8.2520e+03],
#        [1.0000e+00, 1.0000e+01],
#        [0.0000e+00, 0.0000e+00],
#        [7.8500e+02, 1.4675e+04],
#        [7.1100e+02, 1.5340e+03],
#        [1.2000e+02, 2.3300e+02],
#        [1.5000e+02, 3.0300e+02],
#        [5.1100e+02, 1.2938e+04],
#        [3.1300e+02, 6.1600e+02],
#        [8.8000e+01, 1.7200e+02],
#        [4.3200e+02, 1.1270e+03],
#        [1.0600e+02, 2.6700e+02],
#        [1.8000e+02, 4.4700e+02]])

# %%
n_norm = n_table / n_table.sum(axis=1)[:, None]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
# NORMALIZED histogram of cons.conf.idx with subscription overlay 

ourbins = np.column_stack((bins[0:15], bins[1:16]))

p1 = plt.bar(x = ourbins[:,0], height = n_norm[:,0], width = ourbins[:, 1] - ourbins[:, 0], edgecolor='white')
p2 = plt.bar(x = ourbins[:,0], height = n_norm[:,1], width = ourbins[:, 1] - ourbins[:, 0], bottom = n_norm[:,0], edgecolor='white')

plt.legend(['subscription= Yes', 'subscription = No'])
plt.title('NORMALIZED Histogram of cons.conf.idx with subscription Overlay')
plt.xlabel("cons.conf.idx"); plt.ylabel("counts"); plt.show()

# %% [markdown]
# #### the normalized histogram show indifferences when it comes to cons.conf.idx and subscription
# #### investigate further with a two sample t test to ascertain this hypothesis that cons.conf.idx is not a significant
# #### predictor for the target (y-subscription or no)

# %%
import scipy.stats as stats
sample1 = cons_conf_yes
sample2 = cons_conf_no
t_stat, p_val = stats.ttest_ind(sample1, sample2, equal_var=False)
t_stat, p_val
# Out:
# (8.636457755508381, 7.588202230489877e-18)

# %% [markdown]
# ***

# %%
# Exploring cons.price.idx (numerical predictor with the target variable)
import seaborn as sns

# %%
train_data["cons.price.idx"].plot.hist(grid=True, bins=25, rwidth=0.9, color='#607c8e')
plt.xlabel('cons.price.idx')
plt.ylabel('counts')
plt.show()

# %%
# Histogram of cons.price.idx with target variable(y) overlay 

cons_price_yes = train_data[train_data.y=='yes']['cons.price.idx']
cons_price_no = train_data[train_data.y=='no']['cons.price.idx']

plt.hist([cons_price_yes, cons_price_no], bins = 25, stacked = True, rwidth=0.9)
plt.legend(['subscribed = Yes', 'subscribed = No'])
plt.title('Histogram of cons.price.idx with subscription Overlay')
plt.xlabel("cons_price_idx"); plt.ylabel("counts"); plt.show()

# %%
(n, bins, patches) = plt.hist([cons_price_yes, cons_price_no], bins =25, stacked = True, rwidth=0.9)

# %%
n_table = np.column_stack((n[0], n[1]))
n_table
# Out:
# array([[2.640e+02, 7.700e+02],
#        [1.060e+02, 2.670e+02],
#        [2.460e+02, 6.250e+02],
#        [0.000e+00, 0.000e+00],
#        [2.560e+02, 5.290e+02],
#        [1.000e+00, 1.000e+01],
#        [6.500e+02, 6.076e+03],
#        [2.640e+02, 7.150e+02],
#        [4.420e+02, 2.458e+03],
#        [1.900e+02, 3.616e+03],
#        [0.000e+00, 0.000e+00],
#        [1.500e+02, 2.640e+02],
#        [2.710e+02, 5.175e+03],
#        [0.000e+00, 0.000e+00],
#        [0.000e+00, 0.000e+00],
#        [1.390e+02, 2.410e+02],
#        [5.290e+02, 6.897e+03],
#        [3.600e+02, 7.996e+03],
#        [1.070e+02, 2.290e+02],
#        [3.260e+02, 6.140e+02],
#        [0.000e+00, 0.000e+00],
#        [0.000e+00, 0.000e+00],
#        [1.880e+02, 4.374e+03],
#        [9.300e+01, 2.040e+02],
#        [5.800e+01, 1.280e+02]])

# %%
n_norm = n_table / n_table.sum(axis=1)[:, None]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
# NORMALIZED histogram of cons.conf.idx with subscription overlay 

ourbins = np.column_stack((bins[0:25], bins[1:26]))

p1 = plt.bar(x = ourbins[:,0], height = n_norm[:,0], width = ourbins[:, 1] - ourbins[:, 0], edgecolor='white')
p2 = plt.bar(x = ourbins[:,0], height = n_norm[:,1], width = ourbins[:, 1] - ourbins[:, 0], bottom = n_norm[:,0], edgecolor='white')

plt.legend(['subscription= Yes', 'subscription = No'])
plt.title('NORMALIZED Histogram of cons.price.idx with subscription Overlay')
plt.xlabel("cons.price.idx"); plt.ylabel("counts"); plt.show()

# %% [markdown]
# #### the normalized histogram show indifferences when it comes to cons.price.idx and subscription
# #### investigate further with a two sample t test to ascertain this hypothesis that cons.price.idx is not a significant
# #### predictor for the target (y-subscription or no)

# %%
import scipy.stats as stats
sample1 = cons_price_yes
sample2 = cons_price_no
t_stat, p_val = stats.ttest_ind(sample1, sample2, equal_var=False)
t_stat, p_val
# Out:
# (-24.0824669896045, 6.91652141166142e-122)

# %% [markdown]
# ***

# %% [markdown]
# ### EXPLORING Multiple numerical variable in a scatter plot

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
ax = sns.scatterplot(x="age", y="cons.price.idx",size='y', sizes=(70,10), data=train_data)
plt.show()

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
ax = sns.scatterplot(x="age", y="campaign",hue='y', data=train_data)
plt.show()

# %%
train_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df=train_data[['age','campaign', 'cons.price.idx','duration', 'pdays', 'previous',
       'cons.conf.idx', 'euribor3m', 'emp.var.rate', 'nr.employed']]

# %%
plt.figure(figsize=(10,7))
sns.pairplot(df)
plt.show()

# %% [markdown]
# ***

# %%
# exploring euribor3m with the target 
train_data.euribor3m.plot.hist(grid=True, bins=6, rwidth=0.9, color='#607c8e')
plt.xlabel('euribor3m')
plt.ylabel('counts')
plt.show()

# %%
# Histogram of Age with target variable(y) overlay 


euribor_yes = train_data[train_data.y=='yes']['euribor3m']
euribor_no = train_data[train_data.y=='no']['euribor3m']

plt.hist([euribor_yes, euribor_no], bins = 6, stacked = True, rwidth=0.9)
plt.legend(['subscribed = Yes', 'subscribed = No'])
plt.title('Histogram of euribor with subscription Overlay')
plt.xlabel("euribor3m"); plt.ylabel("counts"); plt.show()

# %%
(n, bins, patches) = plt.hist([euribor_yes, euribor_no], bins =6, stacked = True, rwidth=0.9)

# %%
n_table = np.column_stack((n[0], n[1]))
n_table
# Out:
# array([[2.8690e+03, 1.1061e+04],
#        [4.3200e+02, 2.4370e+03],
#        [0.0000e+00, 0.0000e+00],
#        [1.0000e+00, 7.0000e+00],
#        [1.7500e+02, 3.5810e+03],
#        [1.1630e+03, 2.4102e+04]])

# %%
n_norm = n_table / n_table.sum(axis=1)[:, None]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
# NORMALIZED histogram of Age with subscription overlay 

ourbins = np.column_stack((bins[0:6], bins[1:7]))

p1 = plt.bar(x = ourbins[:,0], height = n_norm[:,0], width = ourbins[:, 1] - ourbins[:, 0], edgecolor='white')
p2 = plt.bar(x = ourbins[:,0], height = n_norm[:,1], width = ourbins[:, 1] - ourbins[:, 0], bottom = n_norm[:,0], edgecolor='white')

plt.legend(['subscription= Yes', 'subscription = No'])
plt.title('NORMALIZED Histogram of euribor with subscription Overlay')
plt.xlabel("euribor3m"); plt.ylabel("counts"); plt.show()

# %% [markdown]
# ***
