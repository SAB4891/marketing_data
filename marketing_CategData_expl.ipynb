# %% [markdown]
# ### Exploring the categorical variables with the target (subscription: Y or N)

# %%
#previous outcome with the categorical variable (subscription to the term deposit: Y or N)
crosstab_01 = pd.crosstab(train_data["poutcome"], train_data["y"])
crosstab_01.plot(kind='bar', stacked = True)

# %%
#normalized barplot 
crosstab_norm = crosstab_01.div(crosstab_01.sum(1),axis = 0)
crosstab_norm.plot(kind='bar', stacked = True)

# %% [markdown]
# ***

# %%
# Job with the target variable (subscription to the term deposit: Y or N)
crosstab_01 = pd.crosstab(train_data["job"], train_data["y"])
crosstab_01.plot(kind='bar', stacked = True)

# %%
#normalized barplot 
crosstab_norm = crosstab_01.div(crosstab_01.sum(1),axis = 0)
crosstab_norm.plot(kind='bar', stacked = True)

# %% [markdown]
# ***

# %%
# Education with the target variable (subscription to the term deposit: Y or N)
crosstab_02 = pd.crosstab(train_data["education"], train_data["y"])
crosstab_02.plot(kind='bar', stacked = True)

# %%
#normalized barplot 
crosstab_norm02 = crosstab_02.div(crosstab_02.sum(1),axis = 0)
crosstab_norm02.plot(kind='bar', stacked = True)

# %% [markdown]
# ***

# %%
# Marital status with the target variable (subscription to the term deposit: Y or N)
crosstab_03 = pd.crosstab(train_data["marital"], train_data["y"])
crosstab_03.plot(kind='bar', stacked = True)

# %%
#normalized barplot 
crosstab_norm03 = crosstab_03.div(crosstab_03.sum(1),axis = 0)
crosstab_norm03.plot(kind='bar', stacked = True)
